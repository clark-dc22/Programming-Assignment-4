# %%
import pandas as pd

# %%
df = pd.read_csv('board2.csv')
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
df.describe()
# Out:
#             Math  Electronics       GEAS  Communication
# count  30.000000     30.00000  30.000000      30.000000
# mean   72.166667     61.60000  71.866667      61.966667
# std    12.660237     17.29381  15.725519      15.376837
# min    48.000000     35.00000  40.000000      41.000000
# 25%    64.250000     47.00000  61.250000      49.000000
# 50%    73.500000     60.00000  76.000000      60.000000
# 75%    83.000000     76.50000  83.750000      72.750000
# max    89.000000     91.00000  94.000000      88.000000

# %%
#Code that displays only students from Visayas and has a score less than 70.
Vis = df.loc[(df['Hometown'] == 'Visayas')&(df['Math']<70),['Name','Gender','Track','Math']] 
Vis
# Out:
#    Name  Gender            Track  Math
# 3    S4    Male  Instrumentation    65
# 10  S11  Female    Communication    48
# 21  S22  Female    Communication    64

# %%
#Code that displays students from Luzon, has a track of Instrumentation, and has a score greater than 70 in the track, Electronics.
Instru = df.loc[(df['Hometown'] == 'Luzon') & (df['Track'] == 'Instrumentation') & (df['Electronics'] > 70), ['Name','GEAS','Electronics']]
Instru
# Out:
#    Name  GEAS  Electronics
# 0    S1    75           89
# 7    S8    64           81
# 29  S30    57           81

# %%
Instru.to_csv('Instru.csv')

# %%
#Code that displays female students from Mindanao and has an average greater than or equal to 55.
Mindy = df['Average'] = df[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1) 
df.loc [(df['Gender'] == 'Female') & (df['Hometown'] == 'Mindanao') & (df['Average'] >= 55), ['Name', 'Track', 'Electronics', 'Average']]
# Out:
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %%
Mindy.to_csv('Mindy.csv')

# %%
import matplotlib.pyplot as plt

# %%
#Code that displays the average by each track.
df['Average'] = df[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1) 

avg = df.groupby('Track')['Average'].mean() 

plt.bar (avg.index, avg.values, color = ['red', 'blue', 'yellow']) 
plt.title('Average by Track') 
plt.ylabel('Mean') 
plt.xlabel('Tracks') 
plt.show()

# %%
#Code that displays the average of each gender from each hometown.
avg = df.groupby('Gender')['Average'].mean()
plt.bar (avg.index, avg.values, color = ['red', 'blue', 'yellow']) 
plt.title('Average by Gender') 
plt.ylabel('Mean') 
plt.xlabel('Gender') 
plt.show() # display

# %%
#Code that shows average of each hometown.
avg = df.groupby('Hometown')['Average'].mean() 

plt.bar (avg.index, avg.values, color = ['red', 'blue', 'yellow']) 
plt.title('Average by Hometown') 
plt.ylabel('Mean') 
plt.xlabel('Hometown') 
plt.show()
